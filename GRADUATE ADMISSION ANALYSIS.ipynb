# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as px

# %%
df=pd.read_csv('Admission_Predict.csv')
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.shape
# Out:
# (400, 9)

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
d=pd.read_csv('Admission_Predict_Ver1.1.csv')
d
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
d.shape
# Out:
# (500, 9)

# %%
d.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
final_df=pd.concat([df,d])
final_df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
final_df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  900.000000  900.000000   900.000000         900.000000  900.000000
# mean   228.277778  316.621111   107.288889           3.102222    3.385556
# std    134.674991   11.369700     6.073968           1.143048    0.997612
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    113.000000  308.000000   103.000000           2.000000    2.500000
# 50%    225.500000  317.000000   107.000000           3.000000    3.500000
# 75%    338.000000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  900.00000  900.000000  900.000000        900.000000
# mean     3.47000    8.586433    0.554444          0.722900
# std      0.91319    0.600822    0.497303          0.141722
# min      1.00000    6.800000    0.000000          0.340000
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         900 non-null    int64
#  1   GRE Score          900 non-null    int64
#  2   TOEFL Score        900 non-null    int64
#  3   University Rating  900 non-null    int64
#  4   SOP                900 non-null    float64
#  5   LOR                900 non-null    float64
#  6   CGPA               900 non-null    float64
#  7   Research           900 non-null    int64
#  8   Chance of Admit    900 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 70.3 KB

# %%
#Mean scores 

gre=final_df['GRE Score'].mean()
toefl=final_df['TOEFL Score'].mean()
cgpa=final_df['CGPA'].mean()

sop = np.round(final_df['SOP'].mean())
lor = np.round(final_df['LOR '].mean())

research = np.round(final_df['Research'].mean())
uni_rating = np.round(final_df['University Rating'].mean())

# printing the results

print("The Average Score for GRE is {:.2f}".format(gre))
print("The Average Score for TOEFL is {:.2f}".format(toefl))
print("The Average CGPA is {:.2f}".format(cgpa))
print("The Average Number for Statement of Purpose is", sop)
print("The Average Number for Recommendation letters among the students is", lor)
print("The Average Number of Research done by students is ", research)
print("The Average University Ratings of Different Students is ", uni_rating)
# Out:
# The Average Score for GRE is 316.62
# The Average Score for TOEFL is 107.29
# The Average CGPA is 8.59
# The Average Number for Statement of Purpose is 3.0
# The Average Number for Recommendation letters among the students is 3.0
# The Average Number of Research done by students is  1.0
# The Average University Ratings of Different Students is  3.0

# %%
# Average GRE Score of the students

gre = final_df['GRE Score'].max()
toefl = final_df['TOEFL Score'].max()
cgpa = final_df['CGPA'].max()

# sop - statement of purpose
# lor - letter of recommendation

sop = np.round(final_df['SOP'].max())
lor = np.round(final_df['LOR '].max())

research = np.round(final_df['Research'].max())
uni_rating = np.round(final_df['University Rating'].max())

# printing the results

print("The Maximum Score for GRE is {:.2f}".format(gre))
print("The Maximum Score for TOEFL is {:.2f}".format(toefl))
print("The Maximum CGPA is {:.2f}".format(cgpa))
print("The Maximum Number for Statement of Purpose is", sop)
print("The Maximum Number for Recommendation letters among the students is", lor)
print("The Maximum Number of Research done by students is ", research)
print("The Maximum University Ratings of Different Students is ", uni_rating)
# Out:
# The Maximum Score for GRE is 340.00
# The Maximum Score for TOEFL is 120.00
# The Maximum CGPA is 9.92
# The Maximum Number for Statement of Purpose is 5.0
# The Maximum Number for Recommendation letters among the students is 5.0
# The Maximum Number of Research done by students is  1
# The Maximum University Ratings of Different Students is  5

# %%
# Average GRE Score of the students

gre = final_df['GRE Score'].min()
toefl = final_df['TOEFL Score'].min()
cgpa = final_df['CGPA'].min()

# sop - statement of purpose
# lor - letter of recommendation

sop = np.round(final_df['SOP'].min())
lor = np.round(final_df['LOR '].min())

research = np.round(final_df['Research'].min())
uni_rating = np.round(final_df['University Rating'].min())

# printing the results

# printing the results

print("The Minimum Score for GRE is {:.2f}".format(gre))
print("The Minimum Score for TOEFL is {:.2f}".format(toefl))
print("The Minimum CGPA is {:.2f}".format(cgpa))
print("The Minimum Number for Statement of Purpose is", sop)
print("The Minimum Number for Recommendation letters among the students is", lor)
print("The Minimum Number of Research done by students is ", research)
print("The Minimum University Ratings of Different Students is ", uni_rating)
# Out:
# The Minimum Score for GRE is 290.00
# The Minimum Score for TOEFL is 92.00
# The Minimum CGPA is 6.80
# The Minimum Number for Statement of Purpose is 1.0
# The Minimum Number for Recommendation letters among the students is 1.0
# The Minimum Number of Research done by students is  0
# The Minimum University Ratings of Different Students is  1

# %%
final_df.groupby('University Rating').mean()
# Out:
#                    Serial No.   GRE Score  TOEFL Score       SOP      LOR   \
# University Rating
# 1                  260.866667  304.150000    99.716667  1.916667  2.333333
# 2                  233.600858  309.154506   103.480687  2.693133  2.942060
# 3                  228.003390  315.447458   106.572881  3.333898  3.401695
# 4                  244.301676  323.932961   111.318436  4.044693  3.972067
# 5                  183.293233  328.090226   113.541353  4.488722  4.383459
#
#                        CGPA  Research  Chance of Admit
# University Rating
# 1                  7.775667  0.250000          0.556000
# 2                  8.180515  0.296137          0.626052
# 3                  8.523627  0.535593          0.706949
# 4                  8.971788  0.787709          0.808436
# 5                  9.283985  0.872180          0.888120

# %%
import seaborn as sns 

def Data_visualizations(column_name):
    
    sns.distplot(final_df[column_name],color='red')
    plt.xlabel(column_name)
    plt.ylabel('count')
    plt.show()

# %%
Data_visualizations('GRE Score')
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
def count_plot(column_name):
    
    sns.countplot(final_df[column_name],color='red')
    plt.xlabel(column_name)
    plt.ylabel('count')
    plt.show()

# %%
count_plot('SOP')
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
final_df['Research'].value_counts()
# Out:
# 1    499
# 0    401
# Name: Research, dtype: int64

# %%
# making a pie chart for the analysis of students rather they did research or not.

size = [499, 401]
labels = "Reseach Done", "No Reseach Done"
colors = ['lightblue', 'Red']
explode = [0, 0.1]

plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Pie Chart for Representing Students With Research work', fontsize = 30)
plt.axis('off')
plt.show()

# %%
Y=final_df['Chance of Admit ']
X=final_df.drop('Chance of Admit ',axis=1)

# %%
X
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research
# 0           1
# 1           1
# ...

# %%
Y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 900, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 287         288        324          114                  5  5.0   4.5  9.08
# 305         306        321          109                  3  3.5   3.5  8.80
# 296         297        310          107                  3  3.5   3.5  8.67
# 172         173        322          110                  4  4.0   5.0  9.13
# 463         464        304          107                  3  3.5   3.0  7.86
# ..          ...        ...          ...                ...  ...   ...   ...
# 106         107        329          111                  4  4.5   4.5  9.18
# 270         271        306          105                  2  2.5   3.0  8.22
# 460         461        319          105                  4  4.0   4.5  8.66
# 35           36        320          110                  5  5.0   5.0  9.20
# 102         103        314          106                  2  4.0   3.5  8.25
#
#      Research
# 287         1
# 305         1
# ...

# %%
X_test
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 70           71        332          118                  5  5.0   5.0  9.64
# 427         428        310          101                  3  3.5   5.0  8.65
# 231         232        319          106                  3  3.5   2.5  8.33
# 188         189        331          115                  5  4.5   3.5  9.36
# 39           40        307          108                  2  4.0   3.5  7.70
# ..          ...        ...          ...                ...  ...   ...   ...
# 106         107        329          111                  4  4.5   4.5  9.18
# 253         254        335          115                  4  4.5   4.5  9.68
# 238         239        310          104                  3  2.0   3.5  8.37
# 352         353        303          100                  2  3.0   3.5  8.06
# 281         282        317          110                  3  4.0   4.5  9.11
#
#      Research
# 70          1
# 427         1
# ...

# %%
Y_train
# Out:
# 287    0.89
# 305    0.74
# 296    0.76
# 172    0.86
# 463    0.57
#        ...
# 106    0.87
# 270    0.72
# 460    0.77
# 35     0.88
# 102    0.62
# Name: Chance of Admit , Length: 630, dtype: float64

# %%
Y_test
# Out:
# 70     0.94
# 427    0.71
# 231    0.74
# 188    0.93
# 39     0.48
#        ...
# 106    0.87
# 253    0.93
# 238    0.70
# 352    0.64
# 281    0.80
# Name: Chance of Admit , Length: 270, dtype: float64

# %% [raw]
# LINEAR REGRESSION ALGORITHM

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
dt={'Actual': Y_test, 'Predicted ': y_pred}
data=pd.DataFrame(dt)
data
# Out:
#      Actual  Predicted
# 70     0.94    0.941040
# 427    0.71    0.751585
# 231    0.74    0.682577
# 188    0.93    0.881009
# 39     0.48    0.569637
# ..      ...         ...
# 106    0.87    0.845947
# 253    0.93    0.945814
# 238    0.70    0.665586
# 352    0.64    0.624996
# 281    0.80    0.824608
#
# [270 rows x 2 columns]

# %%
data.to_csv("Linear Regression Results.csv")

# %%
#Errors 

from sklearn import metrics 

print(metrics.mean_absolute_error(Y_test,y_pred))
print(metrics.mean_squared_error(Y_test,y_pred))
print(np.sqrt(metrics.mean_squared_error(Y_test,y_pred)))
print(metrics.explained_variance_score(Y_test,y_pred))
# Out:
# 0.04334081997537352
# 0.003735792273281842
# 0.061121127879660744
# 0.8163240913706478

# %% [markdown]
# Keeping track of every single metric can get tedious, so we pick one or two metrics to evaluate our model. A good practice is to make sure that the mean squared error is low and the explained variance score is high.

# %%
#Accuracy 
print(metrics.r2_score(Y_test,y_pred)*100)
# Out:
# 81.62570039998342

# %% [markdown]
# An R2 score near 1 means that the model is able to predict the data very well.

# %% [raw]
# DECISION TREE ALGORITHM

# %%
from sklearn.tree import DecisionTreeRegressor

regressor=DecisionTreeRegressor()
regressor.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
yd_pred=regressor.predict(X_test)

# %%
data_dt={'Actual':Y_test,'Predicted':yd_pred}

dt1=pd.DataFrame(data_dt)
dt1
# Out:
#      Actual  Predicted
# 70     0.94       0.94
# 427    0.71       0.74
# 231    0.74       0.71
# 188    0.93       0.93
# 39     0.48       0.48
# ..      ...        ...
# 106    0.87       0.87
# 253    0.93       0.93
# 238    0.70       0.70
# 352    0.64       0.68
# 281    0.80       0.80
#
# [270 rows x 2 columns]

# %%
dt1.to_csv('Decision Tree Regressor results.csv')

# %%
from sklearn import metrics 

print(metrics.mean_absolute_error(Y_test,yd_pred))
print(metrics.mean_squared_error(Y_test,yd_pred))
print(np.sqrt(metrics.mean_squared_error(Y_test,yd_pred)))
print(metrics.explained_variance_score(Y_test,yd_pred))
# Out:
# 0.016037037037037044
# 0.0020248148148148144
# 0.04499794233978721
# 0.9008105588618456

# %%
#Accuracy 
print(metrics.r2_score(Y_test,yd_pred)*100)
# Out:
# 90.04105385943319

# %% [raw]
# SVM Algorithm

# %%
from sklearn.svm import SVR

sv_reg=SVR(kernel='linear')
sv_reg.fit(X_train,Y_train)
# Out:
# SVR(kernel='linear')

# %%
ysv_pred=sv_reg.predict(X_test)

# %%
df_svr={'Actual':Y_test,'Predicted':ysv_pred}

data_svr=pd.DataFrame(df_svr)
data_svr
# Out:
#      Actual  Predicted
# 70     0.94   0.894926
# 427    0.71   0.709480
# 231    0.74   0.636158
# 188    0.93   0.875915
# 39     0.48   0.429157
# ..      ...        ...
# 106    0.87   0.790217
# 253    0.93   0.960948
# 238    0.70   0.703801
# 352    0.64   0.566516
# 281    0.80   0.807100
#
# [270 rows x 2 columns]

# %%
data_svr.to_csv('SVM Algo Results.csv')

# %%
from sklearn import metrics

print(metrics.mean_squared_error(Y_test,ysv_pred))
print(metrics.mean_absolute_error(Y_test,ysv_pred))
print(np.sqrt(metrics.mean_squared_error(Y_test,ysv_pred)))
print(metrics.explained_variance_score(Y_test,ysv_pred))
# Out:
# 0.007284758410679978
# 0.06639645012290338
# 0.08535079619241978
# 0.6653787510705405

# %%
#Accuracy 

print(metrics.r2_score(Y_test,ysv_pred)*100)
# Out:
# 64.17029541260142

# %% [raw]
# RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor


rfr = RandomForestRegressor()
rfr.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
yrfr=rfr.predict(X_test)
yrfr
# Out:
# array([0.9377, 0.7221, 0.7283, 0.9274, 0.5171, 0.709 , 0.7103, 0.6001,
#        0.9162, 0.6271, 0.7811, 0.77  , 0.6798, 0.9391, 0.8384, 0.8891,
#        0.5994, 0.9323, 0.9112, 0.6197, 0.8309, 0.7896, 0.7985, 0.7243,
#        0.9202, 0.4258, 0.5756, 0.5504, 0.7661, 0.5648, 0.8685, 0.7904,
#        0.8968, 0.7413, 0.9189, 0.792 , 0.938 , 0.8757, 0.6132, 0.6895,
#        0.5655, 0.5711, 0.6734, 0.4258, 0.7077, 0.6107, 0.9189, 0.7269,
#        0.3948, 0.8699, 0.7111, 0.6589, 0.7541, 0.7049, 0.7044, 0.961 ,
#        0.6972, 0.8345, 0.6808, 0.9697, 0.8871, 0.6432, 0.8005, 0.783 ,
#        0.6602, 0.7165, 0.8419, 0.5897, 0.794 , 0.6964, 0.6646, 0.7567,
#        0.7038, 0.6548, 0.7224, 0.8859, 0.9314, 0.4561, 0.4927, 0.7471,
#        0.6529, 0.8495, 0.7224, 0.6693, 0.5218, 0.477 , 0.7366, 0.7247,
#        0.8305, 0.8342, 0.4817, 0.7829, 0.6263, 0.5858, 0.5403, 0.6968,
#        0.7276, 0.7062, 0.7283, 0.7958, 0.6759, 0.903 , 0.6164, 0.807 ,
# ...

# %%
data_drfr={'Actual':Y_test,'Predicted':yrfr}

drfr=pd.DataFrame(data_drfr)
drfr
# Out:
#      Actual  Predicted
# 70     0.94     0.9377
# 427    0.71     0.7221
# 231    0.74     0.7283
# 188    0.93     0.9274
# 39     0.48     0.5171
# ..      ...        ...
# 106    0.87     0.8609
# 253    0.93     0.9325
# 238    0.70     0.7060
# 352    0.64     0.6589
# 281    0.80     0.7929
#
# [270 rows x 2 columns]

# %%
drfr.to_csv('Random Forest Regressor results.csv')

# %%
print(metrics.mean_squared_error(Y_test,yrfr))
print(metrics.mean_absolute_error(Y_test,yrfr))
print(np.sqrt(metrics.mean_squared_error(Y_test,yrfr)))
print(metrics.explained_variance_score(Y_test,yrfr))
# Out:
# 0.001280441555555557
# 0.022521481481481476
# 0.03578325803438749
# 0.9372055676830041

# %%
#Accuracy 

print(metrics.r2_score(Y_test,yrfr)*100)
# Out:
# 93.70221494103023

# %% [raw]
# XG-BOOST

# %%
from xgboost.sklearn import XGBRegressor

xgb=XGBRegressor()
xgb.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
yxgb_pred=xgb.predict(X_test)
yxgb_pred
# Out:
# array([0.9397172 , 0.7175044 , 0.73389757, 0.9283712 , 0.4807463 ,
#        0.7297401 , 0.7092811 , 0.60930073, 0.9307665 , 0.6491368 ,
#        0.8035861 , 0.79002047, 0.6811542 , 0.9403891 , 0.8400902 ,
#        0.8985047 , 0.6405803 , 0.9387874 , 0.8901009 , 0.57033896,
#        0.820923  , 0.790569  , 0.81917566, 0.717789  , 0.9206182 ,
#        0.43457827, 0.5877481 , 0.47096738, 0.7697969 , 0.5693759 ,
#        0.8688181 , 0.79038554, 0.8991162 , 0.7697872 , 0.925021  ,
#        0.7942932 , 0.950262  , 0.8812977 , 0.65716624, 0.68388873,
#        0.55913323, 0.58948797, 0.71719366, 0.43457827, 0.7089264 ,
#        0.60974646, 0.925021  , 0.71124077, 0.36270884, 0.84265244,
#        0.72038865, 0.6766204 , 0.7848822 , 0.68277997, 0.70986736,
#        0.96374017, 0.7078895 , 0.8397531 , 0.652301  , 0.96957916,
#        0.8806798 , 0.6404529 , 0.80935377, 0.8185534 , 0.6399399 ,
#        0.70074046, 0.83135575, 0.5614212 , 0.80056804, 0.6544102 ,
# ...

# %%
data_xgb={'Actual':Y_test,'Predicted':yxgb_pred}

dxgb=pd.DataFrame(data_xgb)
dxgb
# Out:
#      Actual  Predicted
# 70     0.94   0.939717
# 427    0.71   0.717504
# 231    0.74   0.733898
# 188    0.93   0.928371
# 39     0.48   0.480746
# ..      ...        ...
# 106    0.87   0.865151
# 253    0.93   0.931113
# 238    0.70   0.699854
# 352    0.64   0.676620
# 281    0.80   0.799493
#
# [270 rows x 2 columns]

# %%
dxgb.to_csv("XGBoost Results.csv")

# %%
print(metrics.mean_squared_error(Y_test,yxgb_pred))
print(metrics.mean_absolute_error(Y_test,yxgb_pred))
print(np.sqrt(metrics.mean_squared_error(Y_test,yxgb_pred)))
print(metrics.explained_variance_score(Y_test,yxgb_pred))
# Out:
# 0.0006889329479799506
# 0.011482907780894523
# 0.026247532226477036
# 0.9665672272404715

# %%
#Accuracy 
print(metrics.r2_score(Y_test,yxgb_pred)*100)
# Out:
# 96.61151920007967

# %% [raw]
# EXTRA TREE CLASSFIER

# %%
from sklearn.ensemble import ExtraTreesRegressor



etr = ExtraTreesRegressor()
etr.fit(X_train, Y_train)

etr_pred = etr.predict(X_test)

# %%
data_etr={'Actual':Y_test,'Predicted':etr_pred}

detr=pd.DataFrame(data_etr)
detr
# Out:
#      Actual  Predicted
# 70     0.94     0.9400
# 427    0.71     0.7185
# 231    0.74     0.7134
# 188    0.93     0.9300
# 39     0.48     0.4800
# ..      ...        ...
# 106    0.87     0.8700
# 253    0.93     0.9300
# 238    0.70     0.7000
# 352    0.64     0.6452
# 281    0.80     0.8000
#
# [270 rows x 2 columns]

# %%
detr.to_csv('Extra Tree classifier results.csv')

# %%
print(metrics.mean_squared_error(Y_test,etr_pred))
print(metrics.mean_absolute_error(Y_test,etr_pred))
print(np.sqrt(metrics.mean_squared_error(Y_test,etr_pred)))
print(metrics.explained_variance_score(Y_test,etr_pred))
# Out:
# 0.0009589737037037027
# 0.011130370370370882
# 0.030967300555645835
# 0.9531494025165317

# %%
#Accuracy 

print(metrics.r2_score(Y_test,etr_pred)*100)
# Out:
# 95.2833378166099

# %% [markdown]
# As a result after verifying all the algorithms XGBoost algorithm is the best to use as it has low mean squared error and High accuracy
